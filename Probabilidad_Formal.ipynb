# %% [markdown]
# <a href="https://colab.research.google.com/github/NAvilCap/Probabilidad1/blob/main/Probabilidad_Formal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# Generar datos para la distribucion normal

# %%
media= 70
desv_std= 4
num_datos=500

# %%
datos = np.random.normal(media,desv_std,num_datos)
datos[0:50]
# Out:
# array([70.20664148, 64.21835302, 64.51470128, 69.25019187, 68.2877691 ,
#        68.34979351, 75.45764488, 68.75986937, 71.8251638 , 67.43232719,
#        64.4542709 , 71.20712116, 70.62310185, 60.58592936, 70.26277775,
#        69.05609902, 68.73589338, 64.27755501, 68.80659516, 66.05631547,
#        70.40318947, 69.76542189, 66.50082265, 68.82183282, 63.36423595,
#        72.02396175, 71.26297083, 67.68168999, 68.16631371, 70.73232663,
#        73.38842474, 67.07234226, 69.96731706, 70.07754627, 67.09875015,
#        67.4476292 , 68.57066938, 76.3692956 , 75.97545318, 69.46726371,
#        76.19392634, 60.24893506, 71.49563734, 65.95398829, 76.78303116,
#        69.63276367, 71.79084112, 73.10372138, 76.02022328, 75.5888375 ])

# %%
# # Crear un rango de valores para crear una densidad
x = np. linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)
# Calcular La PDF de La distribución normal
pdf = 1 / (desv_std* np. sqrt(2 *np.pi)) * np.exp(-(x - media)**2 / (2 * desv_std **2))

# %%
# Para no imprimir toda la Lista de valores (500), desplegamos Los primeros 50
print("Imprimir los primeros 50 Valores de x", x[0:50], ", y los primeros 50 pdf", pdf[0:50])
# Out:
# Imprimir los primeros 50 Valores de x [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343] , y los primeros 50 pdf [0.00110796 0.00114858 0.0011905  0.00123379 0.00127846 0.00132455
#  0.00137211 0.00142118 0.00147178 0.00152397 0.00157777 0.00163325
#  0.00169042 0.00174935 0.00181007 0.00187262 0.00193706 0.00200342
#  0.00207176 0.00214212 0.00221455 0.0022891  0.00236581 0.00244475
#  0.00252595 0.00260947 0.00269536 0.00278367 0.00287447 0.0029678
#  0.00306371 0.00316227 0.00326352 0.00336753 0.00347436 0.00358405
#  0.00369667 0.00381228 0.00393094 0.00405271 0.00417764 0.0043058
#  0.00443725 0.00457205 0.00471027 0.00485197 0.0049972  0.00514604
#  0.00529854 0.00545478]

# %%
#Graficar histograma
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, color="b")
plt.title("Distribucion Normal")
plt. xlabel('Peso en kg de los estudiantes')
plt. grid (True)
plt. show()

# %%
# Visualizar La PDF
plt. figure(figsize=(6, 4))
plt. plot(x, pdf, label= 'Normal: (media: (); ds: ())'. format(np. round (media, 2), np. round (desv_std, 2)))
plt. title('Función de Densidad de Probabilidad (PDF) - Distribución Normal')
plt. xlabel( 'Pesos en Kg. de los estudiantes')
plt. ylabel( 'Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt. show()

# %%
# Graficar histograma
plt. figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot( x, pdf, 'k', linewidth=2, )
plt. title( 'Distribución Normal ')
plt. xlabel('Peso en kg de los estudiantes')
plt. grid (True)
plt. show()

# %% [markdown]
# ## Sección nueva Segundo Problema

# %%
plt. figure (figsize=(6, 4))
# Parámetros de la distribución normal
media = 70 # Media
desv_std = 4 # Desviación estándar
total_estudiantes = 500

# VARIABLE para Cálculo de la probabilidad de que un estudiante que pese menos de 75 kg
peso_limite = 79

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acumulativa (CDF) de la
# distribución normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)

# %%
# Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg
print("Probabilidad de que un estudiante pese menos de 75 kg:", prob_menos_75kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_75kg)

# Graficar La distribución normal
x = np. linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt. plot(x, y, 'b', linewidth=2)
plt. fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title( 'Probabilidad de que un estudiante pese menos de 75 kg. \n mu=70$, sigma=45, X=500')
plt. xlabel( 'Peso (kg)')
plt.ylabel( 'Densidad de probabilidad')
plt.grid(True)
plt. show()
776367247766
# Out:
# Probabilidad de que un estudiante pese menos de 75 kg: 0.9877755273449553
# Número de estudiantes que pesan menos de 75 kg: 493.88776367247766
# 776367247766

# %%
plt. figure(figsize=(6, 4))
# Parámetros de la distribución normal
media=70
desv_std = 4
# Desviación estándar
total_estudiantes = 500

# VARIABLE para Cálculo de la probabilidad de que un estudiante pese menos de 75 kg
peso_limite = 62

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acumulativa (CDF) de La distribución normal
prob_menos_62kg = norm.cdf(peso_limite, media, desv_std)

# Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_62kg = total_estudiantes * prob_menos_62kg

print("Probabilidad de que un estudiante pese menos de 62 kg:", prob_menos_62kg)
print( "Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_62kg)
# Out:
# Probabilidad de que un estudiante pese menos de 62 kg: 0.022750131948179195
# Número de estudiantes que pesan menos de 75 kg: 11.375065974089598

# %%
# Calcular la distribución normal
x = np. linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

# Graficar la distribución normal
plt.plot(x, y, 'b', linewidth=2)
plt. fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title( 'Probabilidad de que un estudiante pese menos de 62 kg, \n $\mu=70$, $\sigma=4$, X=500')
plt. xlabel( 'Peso (kg)')
plt.ylabel( 'Densidad de probabilidad')
plt. grid(True)
plt. show ()

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distribución normal
media = 70 # Media
desv_std - 4 # Desviación estándar
peso_limite - 79
# Peso Limite
total_estudiantes = 500
# Calculamos La probabilidad de que un estudiante pese menos o igual a 79 kg
prob_menos_79kg = norm. cdf (peso_limite, media, desv_std)
# La probabilidad de que un estudiante pese más de 79 kg es complementaria
prob_mas_79kg = 1 - prob_menos_79kg
# Calculamos el número aproximado de estudiantes que pesan más de 79 kg
estudiantes_mas_79kg = total_estudiantes * prob_mas_79kg
print("Probabilidad de que un estudiante pese más de 79 kg:", prob_mas_79kg)
print("Número aproximado de estudiantes que pesan más de 79 kg:", estudiantes_mas_79kg)
# Out:
# Probabilidad de que un estudiante pese más de 79 kg: 0.9772498680518208
# Número aproximado de estudiantes que pesan más de 79 kg: 488.6249340259104

# %%
# Calcular la función de densidad de probabilidad de la distribución normal
x = np. linspace(media - 4* desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 79 Kg. \n $\mu=70$, $sigma=4$, X=500')
plt. xlabel( 'Peso (kg)')
plt.ylabel( 'Densidad de probabilidad')
plt. grid (True)
plt. show()

# %% [markdown]
# ## Probabilidad de Estudiantes que pesan mas de 68kg y menos de 72kg

# %%
# Parámetros de la distribución normal
media = 70 # Media
desv_std = 4 # Desviación estándar
peso_limite= 72
peso_limite2=68
# Peso Limite
total_estudiantes = 500
# Calculamos La probabilidad de que un estudiante pese menos o igual a 72 kg
prob_menos_72kg = norm. cdf (peso_limite, media, desv_std)
# La probabilidad de que un estudiante pese menos de 68 o igual
prob_menos_68kg = norm. cdf (peso_limite2, media, desv_std)
#La probabilidad de que un estudiante pese más de 68 kg es complementaria
prob_mas_68kg = 1 - prob_menos_68kg
# Calculamos el número aproximado de estudiantes que pesan más de 68 kg
estudiantes_mas_68kg = total_estudiantes * prob_menos_68kg
#Calculamos el número aproximado de estudiantes que pesan menos de 72 kg
estudiantes_menos_72kg = total_estudiantes * prob_menos_72kg
print("Probabilidad de que un estudiante pese más de 68 kg:", prob_mas_68kg)
print("Número aproximado de estudiantes que pesan más de 68 kg:", estudiantes_mas_68kg)
print("Probabilidad de que un estudiante pese menos de 72 kg:", prob_menos_72kg)
print("Número aproximado de estudiantes que pesan más de 68 kg:", estudiantes_menos_72kg)
#LO que a nosotros nos interesa es conseguir el valor delimitado por estos dos asi que se obtiene de la siguiente forma
prob_estudiante_entre68y72kg =prob_menos_72kg-prob_menos_68kg
#En cantidad seria:
estudiante_entre68y72kg=prob_estudiante_entre68y72kg*total_estudiantes
print("Probabilidad que pesan entre 68 y 72kg:", prob_estudiante_entre68y72kg)
print("NUmero de alumnos que pesan entre 68 y 72kg:", estudiante_entre68y72kg)
# Out:
# Probabilidad de que un estudiante pese más de 68 kg: 0.6914624612740131
# Número aproximado de estudiantes que pesan más de 68 kg: 154.26876936299345
# Probabilidad de que un estudiante pese menos de 72 kg: 0.6914624612740131
# Número aproximado de estudiantes que pesan más de 68 kg: 345.73123063700655
# Probabilidad que pesan entre 68 y 72kg: 0.38292492254802624
# NUmero de alumnos que pesan entre 68 y 72kg: 191.46246127401312

# %%
# Calcular la función de densidad de probabilidad de la distribución normal
x = np. linspace(media - 4* desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=( x <= peso_limite)&( x >= peso_limite2), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 79 Kg. \n $\mu=70$, $sigma=4$, X=500')
plt. xlabel( 'Peso (kg)')
plt.ylabel( 'Densidad de probabilidad')
plt. grid (True)
plt. show()
