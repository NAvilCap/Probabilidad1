# %% [markdown]
# <a href="https://colab.research.google.com/github/NAvilCap/Probabilidad1/blob/main/ProyectFinal_ProbabilidadyEstadistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRÁCTICA FINAL de Regresión y Correlación

# %%
from sklearn.linear_model import LinearRegression #modelo de regresion
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from statistics import*
import math
from google.colab import drive
from scipy.stats import pearsonr

# %%
# Out:
#        HorasEstudio  Calificacion
# count     50.000000      50.00000
# mean      14.352000      83.78820
# std        4.219174       7.83389
# min        3.790000      68.46000
# 25%       12.032500      78.03500
# 50%       14.600000      84.49000
# 75%       17.715000      88.09000
# max       20.000000     100.00000

# %%
df1= pd.read_csv("grupo1.csv")
Horasestudiog1=df1.HorasEstudio
Calificaciong1=df1.Calificacion


df1
# Out:
#     HorasEstudio  Calificacion
# 0          20.00         75.94
# 1          15.60         87.48
# 2          17.91         79.40
# 3          20.00         73.37
# 4          20.00         83.75
# 5          10.09         87.85
# 6          17.80         84.60
# 7          13.39         86.72
# 8          13.59         78.29
# 9          15.64         80.74
# 10         14.58         77.95
# 11         19.82         80.76
# 12         17.04         76.68
# 13         14.49         68.46
# 14         15.78         85.60
# 15         15.33         80.38
# 16         19.98         69.33
# 17         13.18         88.17
# 18         15.25         75.83
# 19         10.58         84.47
# 20          3.79         90.56
# 21         16.61         85.16
# 22         17.46         94.25
# 23         11.03         72.89
# 24         20.00         87.62
# 25          8.18         77.84
# 26         14.18         76.16
# 27         13.25         78.79
# 28         20.00         81.20
# ...

# %%
df1.describe()
# Out:
#        HorasEstudio  Calificacion
# count     50.000000      50.00000
# mean      14.352000      83.78820
# std        4.219174       7.83389
# min        3.790000      68.46000
# 25%       12.032500      78.03500
# 50%       14.600000      84.49000
# 75%       17.715000      88.09000
# max       20.000000     100.00000

# %%
# @title Calificacion Grupo 1

from matplotlib import pyplot as plt
df1['Calificacion'].plot(kind='hist', bins=20, title='Calificacion')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title HorasEstudio vs Calificacion Grupo 1

from matplotlib import pyplot as plt
df1.plot(kind='scatter', x='HorasEstudio', y='Calificacion', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df2= pd.read_csv("grupo2.csv")

Horasestudiog2=np.array(df2.HorasEstudio).reshape(-1,1)
Calificaciong2=np.array(df2.Calificacion)


modelog2=LinearRegression()
modelog2.fit(Horasestudiog2, Calificaciong2)
df2
# Out:
#     HorasEstudio  Calificacion
# 0           3.79          40.0
# 1           6.08          26.1
# 2           7.17          29.0
# 3           7.54          31.9
# 4           8.18          34.8
# 5           8.32          37.7
# 6           8.99          70.0
# 7           9.81          68.0
# 8          10.09          60.0
# 9          10.45          62.0
# 10         10.58          52.2
# 11         11.03          61.0
# 12         11.96          58.0
# 13         12.25          70.0
# 14         12.45          71.3
# 15         12.61          72.6
# 16         12.79          73.9
# 17         13.15          75.2
# 18         13.18          76.5
# 19         13.25          77.8
# 20         13.39          79.1
# 21         13.59          80.4
# 22         14.18          81.7
# 23         14.49          62.0
# 24         14.58          72.0
# 25         14.62          83.0
# 26         14.63          86.9
# 27         15.25          77.0
# 28         15.33          85.0
# ...

# %%
df2.describe()
# Out:
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.912000
# std        4.219174     20.668922
# min        3.790000     26.100000
# 25%       12.032500     63.500000
# 50%       14.600000     78.550000
# 75%       17.715000     93.300000
# max       20.000000     99.000000

# %%
# @title Calificacion Grupo2

from matplotlib import pyplot as plt
df2['Calificacion'].plot(kind='hist', bins=20, title='Calificacion')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df2.plot(kind='scatter', x='HorasEstudio', y='Calificacion', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df3= pd.read_csv("grupo3.csv")

Horasestudiog3=np.array(df3.HorasEstudio).reshape(-1,1)
Calificaciong3=np.array(df3.Calificacion)

modelog3=LinearRegression()
modelog3.fit(Horasestudiog3, Calificaciong3)

df3
# Out:
#     HorasEstudio  Calificacion
# 0           3.79          15.0
# 1           6.08          26.1
# 2           7.17          29.0
# 3           7.54          31.9
# 4           8.18          34.8
# 5           8.32          37.7
# 6           8.99          40.6
# 7           9.81          45.0
# 8          10.09          46.4
# 9          10.45          49.3
# 10         10.58          52.2
# 11         11.03          55.1
# 12         11.96          58.0
# 13         12.25          70.0
# 14         12.45          71.3
# 15         12.61          72.6
# 16         12.79          73.9
# 17         13.15          75.2
# 18         13.18          76.5
# 19         13.25          77.8
# 20         13.39          79.1
# 21         13.59          80.4
# 22         14.18          81.7
# 23         14.49          83.0
# 24         14.58          84.3
# 25         14.62          85.6
# 26         14.63          86.9
# 27         15.25          88.2
# 28         15.33          89.5
# ...

# %%
df3.describe()
# Out:
#        HorasEstudio  Calificacion
# count     50.000000     50.000000
# mean      14.352000     75.968000
# std        4.219174     23.668867
# min        3.790000     15.000000
# 25%       12.032500     61.000000
# 50%       14.600000     84.950000
# 75%       17.715000     94.375000
# max       20.000000     99.000000

# %%
from matplotlib import pyplot as plt
df3['Calificacion'].plot(kind='hist', bins=20, title='Calificacion')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title HorasEstudio vs Calificacion Grupo 3

from matplotlib import pyplot as plt
df3.plot(kind='scatter', x='HorasEstudio', y='Calificacion', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Modelos de Regresion lineal

# %% [markdown]
# Grupo 1

# %%
#Modelo grupo 1

#Datos de entrada

Horasestudiog1 = np.array([Horasestudiog1]).reshape(-1,1)
Calificaciong1=df1.Calificacion

#Crear y entrenar modelo de regresion lineal
modelog1=LinearRegression()
modelog1.fit(Horasestudiog1,Calificaciong1)

#Obtener la ecuación de la línea de regresión (pendiente e intercepto).
pendiente = modelog1.coef_[0]
intercepto = modelog1.intercept_
print("Ecuación de la línea de regresión:")
print(f"Calificaciones = {pendiente:.2f} * Horas de Estudio + {intercepto:.2f}")

print("Valor de la intercepcion:", modelog1.intercept_)
print("Valor de la pendiente:", modelog1.coef_)
# Out:
# Ecuación de la línea de regresión:
# Calificaciones = -0.11 * Horas de Estudio + 85.31
# Valor de la intercepcion: 85.31068185245395
# Valor de la pendiente: [-0.10608151]

# %%
#Crear el diagrama de dispersion con la linea de regresion
plt.figure(figsize=(6,5))
plt.scatter(Horasestudiog1, Calificaciong1, color="blue", label="Datos")
plt.plot(Horasestudiog1, modelog1.predict(Horasestudiog1),color="red", label="Linea de regresion")

plt.title("Pronostico de Calificacion a partir de las Horas de Estudio")
plt.xlabel("Horas de Estudio")
plt.ylabel("Calificacion")
plt.legend()
plt.grid(True)
plt.show()

# %%
from scipy.stats import pearsonr
#Datos de entrada
Horasestudiog1=df1.HorasEstudio
Calificaciong1=df1.Calificacion

#Calcular el coeficiente de correlacion de Pearson
coeficiente_correlacion, p_valor = pearsonr(Horasestudiog1, Calificaciong1)

print("Coeficiente de correlacion de Pearson:", coeficiente_correlacion)
# Out:
# Coeficiente de correlacion de Pearson: -0.057133344466469324

# %% [markdown]
# # Grupo 2

# %%
#Modelo grupo 2

#Datos de entrada

Horasestudiog2 = np.array([Horasestudiog2]).reshape(-1,1)
Calificaciong2=df2.Calificacion

#Crear y entrenar modelo de regresion lineal
modelog2=LinearRegression()
modelog2.fit(Horasestudiog2,Calificaciong2)

#Obtener la ecuación de la línea de regresión (pendiente e intercepto).
pendiente2 = modelog2.coef_[0]
intercepto2 = modelog2.intercept_
print("Ecuación de la línea de regresión:")
print(f"Calificaciones = {pendiente2:.2f} * Horas de Estudio + {intercepto2:.2f}")

print("Valor de la intercepcion:", modelog2.intercept_)
print("Valor de la pendiente:", modelog2.coef_)
# Out:
# Ecuación de la línea de regresión:
# Calificaciones = 4.22 * Horas de Estudio + 15.31
# Valor de la intercepcion: 15.30754188313253
# Valor de la pendiente: [4.22271865]

# %%
#Crear el diagrama de dispersion con la linea de regresion
plt.figure(figsize=(6,5))
plt.scatter(Horasestudiog2, Calificaciong2, color="blue", label="Datos")
plt.plot(Horasestudiog2, modelog2.predict(Horasestudiog2),color="red", label="Linea de regresion")

plt.title("Pronostico de Calificacion a partir de las Horas de Estudio")
plt.xlabel("Horas de Estudio")
plt.ylabel("Calificacion")
plt.legend()
plt.grid(True)
plt.show()

# %%
#Datos de entrada
Horasestudiog2=df2.HorasEstudio
Calificaciong2=df2.Calificacion

#Calcular el coeficiente de correlacion de Pearson
coeficiente_correlacion2, p_valor2 = pearsonr(Horasestudiog2, Calificaciong2)

print("Coeficiente de correlacion de Pearson:", coeficiente_correlacion2)
# Out:
# Coeficiente de correlacion de Pearson: 0.861989042650508

# %% [markdown]
# ## Grupo 3

# %%
#Datos de entrada

Horasestudiog3 = np.array([Horasestudiog3]).reshape(-1,1)
Calificaciong3=df3.Calificacion

#Crear y entrenar modelo de regresion lineal
modelog3=LinearRegression()
modelog3.fit(Horasestudiog3,Calificaciong3)

#Obtener la ecuación de la línea de regresión (pendiente e intercepto).
pendiente3 = modelog3.coef_[0]
intercepto3 = modelog3.intercept_
print("Ecuación de la línea de regresión:")
print(f"Calificaciones = {pendiente3:.2f} * Horas de Estudio + {intercepto3:.2f}")

print("Valor de la intercepcion:", modelog3.intercept_)
print("Valor de la pendiente:", modelog3.coef_)
# Out:
# Ecuación de la línea de regresión:
# Calificaciones = 5.29 * Horas de Estudio + 0.11
# Valor de la intercepcion: 0.10805051830283219
# Valor de la pendiente: [5.28567095]

# %%
#Crear el diagrama de dispersion con la linea de regresion
plt.figure(figsize=(6,5))
plt.scatter(Horasestudiog3, Calificaciong3, color="blue", label="Datos")
plt.plot(Horasestudiog3, modelog3.predict(Horasestudiog3),color="red", label="Linea de regresion")

plt.title("Pronostico de Calificacion a partir de las Horas de Estudio")
plt.xlabel("Horas de Estudio")
plt.ylabel("Calificacion")
plt.legend()
plt.grid(True)
plt.show()

# %%
#Datos de entrada
Horasestudiog3=df3.HorasEstudio
Calificaciong3=df3.Calificacion

#Calcular el coeficiente de correlacion de Pearson
coeficiente_correlacion3, p_valor3 = pearsonr(Horasestudiog3, Calificaciong3)

print("Coeficiente de correlacion de Pearson:", coeficiente_correlacion3)
# Out:
# Coeficiente de correlacion de Pearson: 0.9422151342073145

# %% [markdown]
# # **Interpretacion de Resultados**

# %% [markdown]
# Conforme a los resultados obtenidos en investigacion realizada sobre el archivo podemos deducir en los siguientes puntos relacionados a la interpretacion del coeficiente:
#
# Para el caso 2 y 3 (haciendo referencia a los grupos tomados como ejemplo muestral), la relacion entre horas estudio y calificacion es altamente proporcional de manera positiva, demostrando asi que entre mas horas de estudio, mejor calificacion obtienen, dejandolo de forma mas segura ya que los coeficientes son de  0.861989042650508 y 0.9422151342073145 respectivamentem siendo valores muy cercanos a 1, recordando lo siguiente un coeficiente de correlación de 1 indica una relación lineal positiva perfecta.
#
# Algo que sin duda alguna es sorprendente fue la muestra del grupo 1, en su analisis por medio de la correlacion demostraron poca relacion entre horas de estudio y la calificacion obtenida, teniendo valores de extremo a extremo sin importar un valor del otro, por lo que deja su coeficiente de relacion en tan solo -0.057133344466469324 dejandolo por ultimo como poco fiable, cabe recordar que, un coeficiente de correlación de 0 indica que no hay relación lineal entre las variables.

# %% [markdown]
# # Conclusiones generales

# %% [markdown]
# Para concluir con este tema sobre la correlacion y regrecion lineal, durante la investigacion y trabajo realizado puedo mencionar que es muy util como modelo predictivo ante situaciones donde la relacion es muy marcada como en el caso del grupo 2 y 3 ya que por medio de la investigacion vimos una gran proporcion entre horas estudiadas y calificacion obtenida en los ejemplos antes mencionados.
#
# Situaciones donde no es muy util es como ejemplos parecidos al primer grupo, donde no importa la cantidad de horas estudiadas para obtener mejor calificacion, ya que tanto puedes obtener mejor o peor tanto si estudias poco como mucho, demostrando con este ejemplo casos donde no hay una correlacion y regrecion lineal importante
