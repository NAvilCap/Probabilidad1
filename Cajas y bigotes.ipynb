# %% [markdown]
# <a href="https://colab.research.google.com/github/NAvilCap/Probabilidad1/blob/main/Cajas%20y%20bigotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import*

# %%
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96 ]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
#sacar la media con una formula
promedio =sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#la variable mean saca el promedio o media por medio de la libreria statistics
promedio2= mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
#la funcion type nos devuelve el tipo de variable  de dato
type(grupoa)
# Out:
# list

# %%
tiempos=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]

# %%
prom100m=mean(tiempos)
print("el tiempo promedio de los corredores es:",prom100m)
# Out:
# el tiempo promedio de los corredores es: 17.322

# %%
#median nos ayuda a calcular la mediana de lista
mediana=median(tiempos)
print(mediana)
# Out:
# 17.2

# %%
moda=mode(tiempos)

# %%
print("la moda de los tiempos es:",(moda))
# Out:
# la moda de los tiempos es: 15.1

# %%
multimoda = multimode(tiempos)

# %%
print("las modas son:",multimoda)
# Out:
# las modas son: [15.1, 17.2]

# %% [markdown]
# ## Ejemplo  3: Histogramas de 2 grupos

# %% [markdown]
# # 1)libreria para numero aleatorio

# %%
import random

# %%
fabrica1=[]
for i in range(100):
   numero_aleatorio=round(random.uniform(50,100), 2)
   fabrica1.append(numero_aleatorio)
   print(fabrica1)
# Out:
# [83.49]
# [83.49, 66.18]
# [83.49, 66.18, 65.67]
# [83.49, 66.18, 65.67, 81.89]
# [83.49, 66.18, 65.67, 81.89, 65.66]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52, 99.88]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52, 99.88, 67.66]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52, 99.88, 67.66, 92.39]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52, 99.88, 67.66, 92.39, 65.37]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52, 99.88, 67.66, 92.39, 65.37, 95.33]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52, 99.88, 67.66, 92.39, 65.37, 95.33, 87.37]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52, 99.88, 67.66, 92.39, 65.37, 95.33, 87.37, 69.04]
# [83.49, 66.18, 65.67, 81.89, 65.66, 65.85, 55.57, 51.52, 99.88, 67.66, 92.39, 65.37, 95.33, 87.37, 69.04, 72.66]
# ...

# %%
fabrica2=[]
for i in range(100):
   numero_aleatorio2=round(random.uniform(50,100), 2)
   fabrica2.append(numero_aleatorio2)
   print(fabrica2)
# Out:
# [92.43]
# [92.43, 97.28]
# [92.43, 97.28, 78.04]
# [92.43, 97.28, 78.04, 68.57]
# [92.43, 97.28, 78.04, 68.57, 80.75]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66, 72.62]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66, 72.62, 90.48]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66, 72.62, 90.48, 74.94]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66, 72.62, 90.48, 74.94, 51.17]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66, 72.62, 90.48, 74.94, 51.17, 92.15]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66, 72.62, 90.48, 74.94, 51.17, 92.15, 79.48]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66, 72.62, 90.48, 74.94, 51.17, 92.15, 79.48, 59.27]
# [92.43, 97.28, 78.04, 68.57, 80.75, 51.21, 60.69, 59.66, 72.62, 90.48, 74.94, 51.17, 92.15, 79.48, 59.27, 87.63]
# ...

# %%
#libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion fabrica 2')

# %%
media=mean(fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)

print ("valores de la fabrica1")
print ("Media=",mediana)
print ("mediana=",media)
print ("moda=",moda)
# Out:
# valores de la fabrica1
# Media= 73.86500000000001
# mediana= 75.622
# moda= 83.49

# %%
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)

print ("valores de la fabrica 2")
print ("Media=",mediana2)
print ("mediana=",media2)
print ("moda=",moda2)
# Out:
# valores de la fabrica 2
# Media= 72.78
# mediana= 73.08070000000001
# moda= 99.18

# %%
# generar subplot de renglon 1 por 2 columnas para desplegar 2 histogramas
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#valor minimo, valor maximo, rango
media=mean(fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)

# %%
plt.hist(fabrica1,bins=10, color="b",edgecolor="black", alpha=0.4)
plt.axvline(media, color="b", linestyle="dashed", linewidth=2, label="media")
plt.axvline(mediana, color="r", linestyle="dashed", linewidth=2, label="mediana")
plt.axvline(moda, color="y", linestyle="dashed", linewidth=2, label="moda")
plt.xlabel("valor")
plt.ylabel("frecuencia")
plt.title("Produccion diaria")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2,bins=20, color="b",edgecolor="black", alpha=0.4)
plt.axvline(media, color="b", linestyle="dashed", linewidth=2, label="media")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label="mediana")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label="moda")
plt.xlabel("valor")
plt.ylabel("frecuencia")
plt.title("Produccion diaria")
plt.legend()
plt.show()

# %%
maximo=max(fabrica1)
minimo=min(fabrica1)
rango=maximo-minimo
media=mean(fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)
print("Estadistica descriptiva de la fabrica 1\n","media=",media,"\nmediana=",mediana,"\nmoda=",moda,"\nrango=",rango,"\nmaximo=",maximo,"\nminimo",minimo)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media= 75.622
# mediana= 73.86500000000001
# moda= 83.49
# rango= 49.17999999999999
# maximo= 99.88
# minimo 50.7

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("Estadistica descriptiva de la fabrica 2\n","media=",media2,"\nmediana=",mediana2,"\nmoda=",moda2,"\nrango=",rango2,"\nmaximo=",maximo2,"\nminimo",minimo2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media= 73.08070000000001
# mediana= 72.78
# moda= 99.18
# rango= 49.67999999999999
# maximo= 99.88
# minimo 50.2

# %% [markdown]
#  ##Dispersion de datos

# %%
desviacion_estandar_fabrica1=stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es =",desviacion_estandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es = 14.489369004253227

# %%
desviacion_estandar_fabrica2=stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es =",desviacion_estandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es = 15.257742413130932

# %%
plt.hist(fabrica1,bins=20, color="b",edgecolor="black", alpha=0.4)
plt.axvline(media, color="b", linestyle="dashed", linewidth=2, label=f"media={media:.2f}")
plt.axvline(mediana, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana:.2f}")
plt.axvline(moda, color="y", linestyle="dashed", linewidth=2, label=f"moda={moda:.2f}")

plt.axvline(media-desviacion_estandar_fabrica1, color="g", linestyle="dashed", linewidth=2, label=f"desviacion={desviacion_estandar_fabrica1:.2f}")
plt.axvline(media+desviacion_estandar_fabrica1, color="g", linestyle="dashed", linewidth=2, )

plt.xlabel("valor")
plt.ylabel("frecuencia")
plt.title("Produccion diaria")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2,bins=20, color="b",edgecolor="black", alpha=0.4)
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label=f"media={media2:.2f}")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana2:.2f}")
plt.axvline(moda2, color="y", linestyle="dashed", linewidth=2, label=f"moda={moda2:.2f}")

plt.axvline(media-desviacion_estandar_fabrica2, color="g", linestyle="dashed", linewidth=2, label=f"desviacion={desviacion_estandar_fabrica2:.2f}")
plt.axvline(media+desviacion_estandar_fabrica2, color="g", linestyle="dashed", linewidth=2, )

plt.xlabel("valor")
plt.ylabel("frecuencia")
plt.title("Produccion diaria")
plt.legend()
plt.show()

# %%
plt.boxplot(fabrica1)
plt.title("Produccion de la fabrica")
plt.ylabel("produccion en metros")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(fabrica2)
plt.title("Produccion de la fabrica")
plt.ylabel("produccion en metros")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
##Comparamos la produccion de la fabrica 1 y frabica 2 con diagramas de cajas y bigotes

# %% [markdown]
# ##Comparamos la produccion de la fabrica 1 y frabica 2 con diagramas de cajas y bigotes

# %%
fig, (ax1, ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9,5) )
ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax1.set_title("Produccion de la fafrica 1")
ax2.set_title("Produccion de la fafrica 2")
plt.show()
